# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

pd.options.display.max_columns = None

# %%
df = pd.read_csv("../datos/setas/secondary_data.csv", ";")
# Out:
# /home/adalaber/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3398: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df1 = pd.read_csv("../datos/setas/primary_data.csv", ";")
# Out:
# /home/adalaber/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3398: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df1.head(3)
# Out:
#            family               name class cap-diameter cap-shape Cap-surface  \
# 0  Amanita Family         Fly Agaric     p     [10, 20]    [x, f]      [g, h]
# 1  Amanita Family        Panther Cap     p      [5, 10]    [p, x]         [g]
# 2  Amanita Family  False Panther Cap     p     [10, 15]    [x, f]         NaN
#
#   cap-color does-bruise-or-bleed gill-attachment gill-spacing gill-color  \
# 0    [e, o]                  [f]             [e]          NaN        [w]
# 1       [n]                  [f]             [e]          NaN        [w]
# 2    [g, n]                  [f]             [e]          NaN        [w]
#
#   stem-height stem-width stem-root stem-surface stem-color veil-type  \
# 0    [15, 20]   [15, 20]       [s]          [y]        [w]       [u]
# 1     [6, 10]   [10, 20]       NaN          [y]        [w]       [u]
# 2    [10, 12]   [10, 20]       NaN          NaN        [w]       [u]
#
#   veil-color has-ring ring-type Spore-print-color habitat     season
# ...

# %%
df.head()
# Out:
#   class  cap-diameter cap-shape cap-surface cap-color does-bruise-or-bleed  \
# 0     p         15.26         x           g         o                    f
# 1     p         16.60         x           g         o                    f
# 2     p         14.07         x           g         o                    f
# 3     p         14.17         f           h         e                    f
# 4     p         14.64         x           h         o                    f
#
#   gill-attachment gill-spacing gill-color  stem-height  stem-width stem-root  \
# 0               e          NaN          w        16.95       17.09         s
# 1               e          NaN          w        17.99       18.19         s
# 2               e          NaN          w        17.80       17.74         s
# 3               e          NaN          w        15.77       15.98         s
# 4               e          NaN          w        16.53       17.20         s
#
# ...

# %%
df.columns
# Out:
# Index(['class', 'cap-diameter', 'cap-shape', 'cap-surface', 'cap-color',
#        'does-bruise-or-bleed', 'gill-attachment', 'gill-spacing', 'gill-color',
#        'stem-height', 'stem-width', 'stem-root', 'stem-surface', 'stem-color',
#        'veil-type', 'veil-color', 'has-ring', 'ring-type', 'spore-print-color',
#        'habitat', 'season'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61069 entries, 0 to 61068
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   class                 61069 non-null  object
#  1   cap-diameter          61069 non-null  float64
#  2   cap-shape             61069 non-null  object
#  3   cap-surface           46949 non-null  object
#  4   cap-color             61069 non-null  object
#  5   does-bruise-or-bleed  61069 non-null  object
#  6   gill-attachment       51185 non-null  object
#  7   gill-spacing          36006 non-null  object
#  8   gill-color            61069 non-null  object
#  9   stem-height           61069 non-null  float64
#  10  stem-width            61069 non-null  float64
#  11  stem-root             9531 non-null   object
#  12  stem-surface          22945 non-null  object
#  13  stem-color            61069 non-null  object
#  14  veil-type             3177 non-null   object
# ...

# %%
df.shape
# Out:
# (61069, 21)

# %%
df.describe().T
# Out:
#                 count       mean        std   min   25%    50%    75%     max
# cap-diameter  61069.0   6.733854   5.264845  0.38  3.48   5.86   8.54   62.34
# stem-height   61069.0   6.581538   3.370017  0.00  4.64   5.95   7.74   33.92
# stem-width    61069.0  12.149410  10.035955  0.00  5.21  10.19  16.57  103.91

# %%
df.describe(include='object').T
# Out:
#                       count unique top   freq
# class                 61069      2   p  33888
# cap-shape             61069      7   x  26934
# cap-surface           46949     11   t   8196
# cap-color             61069     12   n  24218
# does-bruise-or-bleed  61069      2   f  50479
# gill-attachment       51185      7   a  12698
# gill-spacing          36006      3   c  24710
# gill-color            61069     12   w  18521
# stem-root              9531      5   s   3177
# stem-surface          22945      8   s   6025
# stem-color            61069     13   w  22926
# veil-type              3177      1   u   3177
# veil-color             7413      6   w   5474
# has-ring              61069      2   f  45890
# ring-type             58598      8   f  48361
# spore-print-color      6354      7   k   2118
# habitat               61069      8   d  44209
# season                61069      4   a  30177

# %% [markdown]
# ## Explicar los datos y las variables disponibles en el conjunto de datos seleccionado

# %% [markdown]
# Se trata de un set de datos de diferentes características de setas. El objetivo es generar un modelo que nos permita determinar si una seta es venenosa o comestible a partir de una serie de características morfológicas. Para ello utilizaremos como variable respuesta a la columna 'class'.
#
# ***
#
# - Variables numéricas:
#
#     - cap-diameter (m): float number in cm
#     - stem-height (m): float number in cm
#     - stem-width (m): float number in mm
#  ***
#
# - Variables categóricas:
#
#     - class: poisonous=p, edibile=e (binary)
#     - cap-shape (n): bell=b, conical=c, convex=x, flat=f,
#     sunken=s, spherical=p, others=o
#     - cap-surface (n): fibrous=i, grooves=g, scaly=y, smooth=s,
#     shiny=h, leathery=l, silky=k, sticky=t,
#     wrinkled=w, fleshy=e
#     - cap-color (n): brown=n, buff=b, gray=g, green=r, pink=p,
#     purple=u, red=e, white=w, yellow=y, blue=l,
#     orange=o, black=k
#     - does-bruise-bleed (n): bruises-or-bleeding=t,no=f
#     - gill-attachment (n): adnate=a, adnexed=x, decurrent=d, free=e,
#     sinuate=s, pores=p, none=f, unknown=?
#     - gill-spacing (n): close=c, distant=d, none=f
#     - gill-color (n): see cap-color + none=f
#     - stem-root (n): bulbous=b, swollen=s, club=c, cup=u, equal=e,
#     rhizomorphs=z, rooted=r
#     - stem-surface (n): see cap-surface + none=f
#     - stem-color (n): see cap-color + none=f
#     - veil-type (n): partial=p, universal=u
#     - veil-color (n): see cap-color + none=f
#     - has-ring (n): ring=t, none=f
#     - ring-type (n): cobwebby=c, evanescent=e, flaring=r, grooved=g,
#     large=l, pendant=p, sheathing=s, zone=z, scaly=y, movable=m, none=f, unknown=?
#     - spore-print-color (n): see cap color
#     - habitat (n): grasses=g, leaves=l, meadows=m, paths=p, heaths=h,
#     urban=u, waste=w, woods=d
#     - season (n): spring=s, summer=u, autumn=a, winter=w
#
# ***

# %% [markdown]
# ## Realizar un EDA sencillo poniendo en práctica los conocimientos adquiridos hasta el momento.

# %% [markdown]
# ### Exploramos el dataset, hacemos tratamiento de duplicados, nulos y cambiamos tipos de datos

# %%
df.head()
# Out:
#   class  cap-diameter cap-shape cap-surface cap-color does-bruise-or-bleed  \
# 0     p         15.26         x           g         o                    f
# 1     p         16.60         x           g         o                    f
# 2     p         14.07         x           g         o                    f
# 3     p         14.17         f           h         e                    f
# 4     p         14.64         x           h         o                    f
#
#   gill-attachment gill-spacing gill-color  stem-height  stem-width stem-root  \
# 0               e          NaN          w        16.95       17.09         s
# 1               e          NaN          w        17.99       18.19         s
# 2               e          NaN          w        17.80       17.74         s
# 3               e          NaN          w        15.77       15.98         s
# 4               e          NaN          w        16.53       17.20         s
#
# ...

# %%
df.shape
# Out:
# (61069, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61069 entries, 0 to 61068
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   class                 61069 non-null  object
#  1   cap-diameter          61069 non-null  float64
#  2   cap-shape             61069 non-null  object
#  3   cap-surface           46949 non-null  object
#  4   cap-color             61069 non-null  object
#  5   does-bruise-or-bleed  61069 non-null  object
#  6   gill-attachment       51185 non-null  object
#  7   gill-spacing          36006 non-null  object
#  8   gill-color            61069 non-null  object
#  9   stem-height           61069 non-null  float64
#  10  stem-width            61069 non-null  float64
#  11  stem-root             9531 non-null   object
#  12  stem-surface          22945 non-null  object
#  13  stem-color            61069 non-null  object
#  14  veil-type             3177 non-null   object
# ...

# %%
# vemos el porcentaje de nulos en nuestras columnas

df.isnull().sum()*100/df.shape[0]
# Out:
# class                    0.000000
# cap-diameter             0.000000
# cap-shape                0.000000
# cap-surface             23.121387
# cap-color                0.000000
# does-bruise-or-bleed     0.000000
# gill-attachment         16.184971
# gill-spacing            41.040462
# gill-color               0.000000
# stem-height              0.000000
# stem-width               0.000000
# stem-root               84.393064
# stem-surface            62.427746
# stem-color               0.000000
# veil-type               94.797688
# veil-color              87.861272
# has-ring                 0.000000
# ring-type                4.046243
# spore-print-color       89.595376
# habitat                  0.000000
# season                   0.000000
# dtype: float64

# %% [markdown]
# Hemos decidido que si tenemos un porcentaje mayor a 40% de nulos, eliminaremos la columna. Si es menos, haremos tratamiento de nulos.
#
#  - eliminar --> gill-spacing, stem-root, stem-surface, veil-type, veil-color, spore-print-color
#  - tratar_nulos --> cap-surface, gill-attachment, ring-type

# %%
# eliminamos las columnas que ya no nos interesan

eliminar = ["gill-spacing", "stem-root", "stem-surface", "veil-type", "veil-color", "spore-print-color"]
df.drop(eliminar, axis = 1, inplace = True)

# %%
# reemplazamos los nulos de las columnas con menos de 40% de nulos por la moda. 

df["cap-surface"].fillna(df["cap-surface"].mode()[0], inplace= True)
df["gill-attachment"].fillna(df["gill-attachment"].mode()[0], inplace= True) 
df["ring-type"].fillna(df["ring-type"].mode()[0], inplace= True)

# %%
# vemos si tenemos duplicados en nuestro dataset

df.duplicated().sum()
# Out:
# 146

# %%
# eliminamos nuestras filas repetidas

df.drop_duplicates(inplace=True)

# %%
# casteamos nuestras columnas de tipo 'object' a tipo category

columnas_categoria = df.select_dtypes("object")

for i in columnas_categoria:
    df[i] = df[i].astype("category")

# %%
# volvemos a hacer un info() para chequear que no tenemos nulos, hemos eliminado filas duplicadas y se ha hecho el cambio 
# de tipo de dato en las columnas correspondientes

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 60923 entries, 0 to 61068
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   class                 60923 non-null  category
#  1   cap-diameter          60923 non-null  float64
#  2   cap-shape             60923 non-null  category
#  3   cap-surface           60923 non-null  category
#  4   cap-color             60923 non-null  category
#  5   does-bruise-or-bleed  60923 non-null  category
#  6   gill-attachment       60923 non-null  category
#  7   gill-color            60923 non-null  category
#  8   stem-height           60923 non-null  float64
#  9   stem-width            60923 non-null  float64
#  10  stem-color            60923 non-null  category
#  11  has-ring              60923 non-null  category
#  12  ring-type             60923 non-null  category
#  13  habitat               60923 non-null  category
# ...

# %% [markdown]
# ### Gráficos

# %% [markdown]
# #### Variable respuesta: 'class'
# Nuestra variable respuesta es binaria y nos indica si la seta es venenosa (poisonous = 'p') o comestible (edible = 'e').

# %%
# graficamos nuestra variable respuesta

plt.figure(figsize=(8,5)) # para cambiar el tamaño de la figura

fig1 = sns.countplot(data = df, x = "class", color = "mediumaquamarine", edgecolor='black')
fig1.set(xticklabels=["Edible", "Poisonous"]) 
plt.show();

# %%
# ¿en porcentaje esto que significa?
df["class"].value_counts() / df.shape[0]
# Out:
# p    0.553847
# e    0.446153
# Name: class, dtype: float64

# %%
columnas_categoria.shape
# Out:
# (60923, 12)

# %% [markdown]
# #### Variables predictoras

# %%
# Gráfico de distribución para cada variable categórica
# ==============================================================================

fig, axes = plt.subplots(nrows = 6, ncols = 2, figsize = (20, 30))

axes = axes.flat
columnas_cat = df.select_dtypes(include = "category").drop('class', axis=1).columns

for i, colum in enumerate(columnas_cat): 
    sns.countplot(
    data = df,
    x = colum,
    hue = "class",
    alpha = 0.5, 
    ax = axes[i])


    axes[i].set_title(colum, fontsize = 15, fontweight = "bold")
    axes[i].tick_params(labelsize = 20)
    axes[i].set_xlabel("")
    axes[i].legend(loc= "upper right")

fig.tight_layout();

# %%
df_numericas = df.select_dtypes(include = np.number)
df_numericas.head()
# Out:
#    cap-diameter  stem-height  stem-width
# 0         15.26        16.95       17.09
# 1         16.60        17.99       18.19
# 2         14.07        17.80       17.74
# 3         14.17        15.77       15.98
# 4         14.64        16.53       17.20

# %%
# Gráfico de distribución para cada variable numérica
# ==============================================================================

fig, axes = plt.subplots(nrows = 1, ncols = 3, figsize = (30, 10))

lista_colores = ["blue", "green", "orange"]

axes = axes.flat

columnas_numeric = df.select_dtypes(include = np.number).columns


for i, colum in enumerate(columnas_numeric): 
    sns.histplot(
    data = df,
    hue = df['class'],
    x = colum,
    kde = True, 
    color = lista_colores[i], 
    line_kws = {"linewidth": 2}, 
    alpha = 0.2, 
    ax = axes[i]) 

    axes[i].set_title(colum, fontsize = 15, fontweight = "bold")
    axes[i].tick_params(labelsize = 20)
    axes[i].set_xlabel("")

fig.tight_layout();

# %%
# creamos la matriz de correlación
correlacion = df_numericas.corr()
correlacion
# Out:
#               cap-diameter  stem-height  stem-width
# cap-diameter      1.000000     0.421718    0.695047
# stem-height       0.421718     1.000000    0.433214
# stem-width        0.695047     0.433214    1.000000

# %%
plt.figure(figsize=(15,8))
mask = np.triu(np.ones_like(correlacion, dtype=bool))
sns.heatmap(correlacion, cmap="viridis", annot = True, mask = mask); #barra lateral

# %%
fig, axes = plt.subplots(3,1, figsize=(10,15))


axes = axes.flat

for indice, cate in enumerate(df_numericas):

    sns.boxplot(x = df[cate], data = df, ax=axes[indice], color = "cyan"); # para trazar una línea de densidad

    axes[indice].set_title(cate)
    axes[indice].set_xlabel("")

fig.tight_layout();

# %% [markdown]
# Vamos a tener que hacer algo con los outliers...

# %%
lista_columnas = df_numericas.columns
lista_columnas
# Out:
# Index(['cap-diameter', 'stem-height', 'stem-width'], dtype='object')

# %%
def detectar_outliers(lista_columnas, dataframe): 

    dicc_indices = {} # creamos un diccionario donde almacenaremos índices de los outliers

# iteramos por la lista de las columnas numéricas de nuestro dataframe
    for col in lista_columnas:

#calculamos los cuartiles Q1 y Q3
        Q1 = np.nanpercentile(dataframe[col], 25)
        Q3 = np.nanpercentile(dataframe[col], 75)

# calculamos el rango intercuartil
        IQR = Q3 - Q1

# calculamos los límites
        outlier_step = 1.5 * IQR

# filtramos nuestro dataframe para indentificar los outliers
        outliers_data = dataframe[(dataframe[col] < Q1 - outlier_step) | (dataframe[col] > Q3 + outlier_step)]


        if outliers_data.shape[0] > 0: # chequeamos si nuestro dataframe tiene alguna fila. 

            dicc_indices[col] = (list(outliers_data.index)) # si tiene fila es que hay outliers y por lo tanto lo añadimos a nuestro diccionario 

    return dicc_indices

# %%
# aplicamos la función y sacamos los índices de los outliers.

ind = detectar_outliers(lista_columnas, df)

ind.keys()
# Out:
# dict_keys(['cap-diameter', 'stem-height', 'stem-width'])

# %%
len(ind['cap-diameter'])
# Out:
# 2389

# %%
len(ind['stem-height'])
# Out:
# 4084

# %%
len(ind['stem-width'])
# Out:
# 1980

# %%
len(ind['cap-diameter']) + len(ind['stem-height']) + len(ind['stem-width'])
# Out:
# 8453

# %%
ind_tot = set(ind['cap-diameter'] + ind['stem-height'] + ind['stem-width'])
len(ind_tot)
# Out:
# 6255

# %%
df.shape
# Out:
# (60923, 15)

# %% [markdown]
# Hemos identificado que en las 3 variables numéricas tenemos una gran cantidad de outliers. Gracias a nuestro segundo dataset, hemos comprobado que estos outliers corresponden a un grupo de especies reducido. Hemos decidido eliminar estas especies de nuestro modelo actual y en un futuro tratarlas aparte.

# %%
df = df.drop(labels=ind_tot, axis=0)

# %%
df.shape
# Out:
# (54668, 15)

# %%
# volvemos a graficar nuestras variables numéricas despues de haber eliminado los outliers. 

fig, axes = plt.subplots(3,1, figsize=(10,15))


axes = axes.flat

for indice, cate in enumerate(df_numericas):

    sns.boxplot(x = df[cate], data = df, ax=axes[indice], color = "cyan"); # para trazar una línea de densidad

    axes[indice].set_title(cate)
    axes[indice].set_xlabel("")

fig.tight_layout();

# %%
# volvemos a graficar la distribución de nuestras variables numéricas sin outliers

fig, axes = plt.subplots(nrows = 1, ncols = 3, figsize = (30, 10))

lista_colores = ["blue", "green", "orange"]

axes = axes.flat

columnas_numeric = df.select_dtypes(include = np.number).columns


for i, colum in enumerate(columnas_numeric): 
    sns.histplot(
    data = df,
    hue = df['class'],
    x = colum,
    kde = True, 
    color = lista_colores[i], 
    line_kws = {"linewidth": 2}, 
    alpha = 0.2, 
    ax = axes[i]) 

    axes[i].set_title(colum, fontsize = 15, fontweight = "bold")
    axes[i].tick_params(labelsize = 20)
    axes[i].set_xlabel("")

fig.tight_layout();

# %%
df.isnull().sum()
# Out:
# class                   0
# cap-diameter            0
# cap-shape               0
# cap-surface             0
# cap-color               0
# does-bruise-or-bleed    0
# gill-attachment         0
# gill-color              0
# stem-height             0
# stem-width              0
# stem-color              0
# has-ring                0
# ring-type               0
# habitat                 0
# season                  0
# dtype: int64

# %%
df.to_pickle('../datos/setas/setas_limpio.pkl')

# %% [markdown]
# ## Interpretación de los resultados.
